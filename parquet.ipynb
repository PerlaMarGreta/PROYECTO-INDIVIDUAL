# %%
import pandas as pd

# Cargar el archivo CSV
data = pd.read_csv("Movies/dataclean.csv")

# Guardar el archivo en formato Parquet
data.to_parquet("dataclean.parquet", engine="pyarrow")  # Cambia "pyarrow" a "fastparquet" si usas esa librería
